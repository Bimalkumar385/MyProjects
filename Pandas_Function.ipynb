# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.DataFrame({"names":["Bimal","Ujjwal","Niyaz"],
                  "college":["PES","PES","PES"],
                  "address":["Bihar","Bihar","Kashmir"]})

# %%
df
# Out:
#     names college  address
# 0   Bimal     PES    Bihar
# 1  Ujjwal     PES    Bihar
# 2   Niyaz     PES  Kashmir

# %%
df.head()
# Out:
#     names college  address
# 0   Bimal     PES    Bihar
# 1  Ujjwal     PES    Bihar
# 2   Niyaz     PES  Kashmir

# %%
df.tail()
# Out:
#     names college  address
# 0   Bimal     PES    Bihar
# 1  Ujjwal     PES    Bihar
# 2   Niyaz     PES  Kashmir

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   names    3 non-null      object
#  1   college  3 non-null      object
#  2   address  3 non-null      object
# dtypes: object(3)
# memory usage: 100.0+ bytes

# %%
df.describe()
# Out:
#         names college address
# count       3       3       3
# unique      3       1       2
# top     Bimal     PES   Bihar
# freq        1       3       2

# %%
df = pd.read_csv("C:\\Users\\Bimal Kumar\\Downloads\\supermarket_sales - Sheet1.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108    NaN     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69       7.0  26.1415   548.9715
# 1    Electronic accessories       15.28       5.0   3.8200    80.2200
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108    NaN     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69       7.0  26.1415  548.9715
# 1  Electronic accessories       15.28       5.0   3.8200   80.2200
# 2      Home and lifestyle       46.33       7.0  16.2155  340.5255
# 3       Health and beauty       58.22       NaN  23.2880  489.0480
# 4       Sports and travel       86.31       7.0  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# ...

# %%
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108    NaN     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167    NaN     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69       7.0  26.1415  548.9715
# 1  Electronic accessories       15.28       5.0   3.8200   80.2200
# 2      Home and lifestyle       46.33       7.0  16.2155  340.5255
# 3       Health and beauty       58.22       NaN  23.2880  489.0480
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total        Date   Time  Payment  \
# 995       40.35       1.0   2.0175    42.3675   1/29/2019  13:46  Ewallet
# 996       97.38      10.0  48.6900  1022.4900  03-02-2019  17:16  Ewallet
# 997       31.84       1.0   1.5920    33.4320  02-09-2019  13:22     Cash
# 998       65.82       1.0   3.2910    69.1110   2/22/2019  15:33     Cash
# 999       88.34       7.0  30.9190   649.2990   2/18/2019  13:28     Cash
#
# ...

# %%
df.tail(10)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 990  886-18-2897      A     Yangon        Normal  Female
# 991  602-16-6955      B   Mandalay        Normal  Female
# 992  745-74-0715      A     Yangon        Normal    Male
# 993  690-01-6631      B   Mandalay        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 990      Food and beverages       56.56       5.0  14.1400   296.9400
# 991       Sports and travel       76.60      10.0  38.3000   804.3000
# 992  Electronic accessories       58.03       2.0   5.8030   121.8630
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108    NaN     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69       7.0  26.1415   548.9715
# 1    Electronic accessories       15.28       5.0   3.8200    80.2200
# ...

# %%
df.describe()
# Out:
#         Unit price    Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  997.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130    5.511535    15.379369   322.966749   307.58738
# std      26.494628    2.924608    11.708825   245.885335   234.17651
# min      10.080000    1.000000     0.508500    10.678500    10.17000
# 25%      32.875000    3.000000     5.924875   124.422375   118.49750
# 50%      55.230000    5.000000    12.088000   253.848000   241.76000
# 75%      77.935000    8.000000    22.445250   471.350250   448.90500
# max      99.960000   10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# 25%                   4.761905      5.924875     5.50000
# ...

# %%
df.Quantity
# Out:
# 0       7.0
# 1       5.0
# 2       7.0
# 3       NaN
# 4       7.0
#        ...
# 995     1.0
# 996    10.0
# 997     1.0
# 998     1.0
# 999     7.0
# Name: Quantity, Length: 1000, dtype: float64

# %%
df["City"]
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object

# %%
df.iloc[:3,:4]
# Out:
#     Invoice ID Branch       City Customer type
# 0  750-67-8428      A     Yangon        Member
# 1  226-31-3081      C  Naypyitaw        Normal
# 2  631-41-3108    NaN     Yangon        Normal

# %%
df.iloc[:8,:5]
# Out:
#     Invoice ID Branch       City Customer type  Gender
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108    NaN     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female

# %%
df["Quantity"].mean()
# Out:
# 5.511534603811434

# %%
df["Total"].mean()
# Out:
# 322.966749

# %%
df.isnull()
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False   False         False
# 2         False    True  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# ..          ...     ...    ...            ...     ...           ...
# 995       False   False  False          False   False         False
# 996       False   False  False          False   False         False
# 997       False   False  False          False   False         False
# 998       False   False  False          False   False         False
# 999       False   False  False          False   False         False
#
#      Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 0         False     False   False  False  False  False    False  False
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     3
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   3
# Tax 5%                     0
# Total                      0
# Date                       2
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.loc[:4,["Product line","Quantity"]]
# Out:
#              Product line  Quantity
# 0       Health and beauty       7.0
# 1  Electronic accessories       5.0
# 2      Home and lifestyle       7.0
# 3       Health and beauty       NaN
# 4       Sports and travel       7.0

# %%
df.loc[:10,["Time","Payment"]]
# Out:
#      Time      Payment
# 0   13:08      Ewallet
# 1   10:29         Cash
# 2   13:23  Credit card
# 3   20:33      Ewallet
# 4   10:37      Ewallet
# 5   18:30      Ewallet
# 6   14:36      Ewallet
# 7   11:38      Ewallet
# 8   17:15  Credit card
# 9   13:27  Credit card
# 10  18:07      Ewallet

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     3
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   3
# Tax 5%                     0
# Total                      0
# Date                       2
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
mq = df["Quantity"].mean()

# %%
mq
# Out:
# 5.511534603811434

# %%
df["Quantity"] = df["Quantity"].fillna(mq)

# %%
df["Quantity"]
# Out:
# 0       7.000000
# 1       5.000000
# 2       7.000000
# 3       5.511535
# 4       7.000000
#          ...
# 995     1.000000
# 996    10.000000
# 997     1.000000
# 998     1.000000
# 999     7.000000
# Name: Quantity, Length: 1000, dtype: float64

# %%
mq = df["Unit price"].mean()

# %%
mq
# Out:
# 55.67213

# %%
mq = df["Quantity"].mean()

# %%
mq
# Out:
# 5.511534603811435

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     3
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       2
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
a=[1,5,7]

# %%
pd.Series(a)
# Out:
# 0    1
# 1    5
# 2    7
# dtype: int64

# %%
pd.Series(a[1])
# Out:
# 0    5
# dtype: int64

# %%
myvar = pd.Series(a,index=["x","y","z"])

# %%
myvar
# Out:
# x    1
# y    5
# z    7
# dtype: int64

# %%
myvar["z"]
# Out:
# 7

# %%
db = pd.DataFrame({"names":["Bimal","Ujjwal","Niyaz"],
                  "college":["PES","PES","PES"],
                  "address":["Bihar","Bihar","Kashmir"]})

# %%
df.loc[0]
# Out:
# Invoice ID                       750-67-8428
# Branch                                     A
# City                                  Yangon
# Customer type                         Member
# Gender                                Female
# Product line               Health and beauty
# Unit price                             74.69
# Quantity                                 7.0
# Tax 5%                               26.1415
# Total                               548.9715
# Date                              01-05-2019
# Time                                   13:08
# Payment                              Ewallet
# cogs                                  522.83
# gross margin percentage             4.761905
# gross income                         26.1415
# Rating                                   9.1
# Name: 0, dtype: object

# %%
db.loc[0]
# Out:
# names      Bimal
# college      PES
# address    Bihar
# Name: 0, dtype: object

# %%
db.loc[1]
# Out:
# names      Ujjwal
# college       PES
# address     Bihar
# Name: 1, dtype: object

# %%
db.loc[[0,1]]
# Out:
#     names college address
# 0   Bimal     PES   Bihar
# 1  Ujjwal     PES   Bihar

# %%
db = pd.DataFrame({"names":["Bimal",np.nan,"Niyaz"],
                  "college":["PES","PES","PES"],
                  "address":["Bihar","Bihar","Kashmir"]})

# %%
db
# Out:
#    names college  address
# 0  Bimal     PES    Bihar
# 1    NaN     PES    Bihar
# 2  Niyaz     PES  Kashmir

# %%
db.isnull()
# Out:
#    names  college  address
# 0  False    False    False
# 1   True    False    False
# 2  False    False    False

# %%
db.isnull().sum()
# Out:
# names      1
# college    0
# address    0
# dtype: int64

# %%
db.dropna()
# Out:
#    names college  address
# 0  Bimal     PES    Bihar
# 2  Niyaz     PES  Kashmir

# %%
db
# Out:
#    names college  address
# 0  Bimal     PES    Bihar
# 1    NaN     PES    Bihar
# 2  Niyaz     PES  Kashmir

# %%
db = pd.DataFrame({"names":["Bimal","Ujjwal","Niyaz"],
                  "college":["PES","PES","PES"],
                  "address":["Bihar","Bihar","Kashmir"],
                  "ID":["015","112","060"]})

# %%
for i,j in db.iterrows():
    print(i,j)
    print()
# Out:
# 0 names      Bimal
# college      PES
# address    Bihar
# ID           015
# Name: 0, dtype: object
#
# 1 names      Ujjwal
# college       PES
# address     Bihar
# ID            112
# Name: 1, dtype: object
#
# 2 names        Niyaz
# college        PES
# address    Kashmir
# ID             060
# Name: 2, dtype: object

# %%
for i in db.iterrows():
    print(i)
    print()
# Out:
# (0, names      Bimal
# college      PES
# address    Bihar
# ID           015
# Name: 0, dtype: object)
#
# (1, names      Ujjwal
# college       PES
# address     Bihar
# ID            112
# Name: 1, dtype: object)
#
# (2, names        Niyaz
# college        PES
# address    Kashmir
# ID             060
# Name: 2, dtype: object)

# %%
for j in db.iterrows():
    print(j)
    print()
# Out:
# (0, names      Bimal
# college      PES
# address    Bihar
# ID           015
# Name: 0, dtype: object)
#
# (1, names      Ujjwal
# college       PES
# address     Bihar
# ID            112
# Name: 1, dtype: object)
#
# (2, names        Niyaz
# college        PES
# address    Kashmir
# ID             060
# Name: 2, dtype: object)

# %%
n=list(db)

# %%
n
# Out:
# ['names', 'college', 'address', 'ID']

# %%
column=n

for i in column:
    print(db[i][2])
# Out:
# Niyaz
# PES
# Kashmir
# 060

# %%
db
# Out:
#     names college  address   ID
# 0   Bimal     PES    Bihar  015
# 1  Ujjwal     PES    Bihar  112
# 2   Niyaz     PES  Kashmir  060

# %%
db.memory_usage(deep=True)
# Out:
# Index       64
# names      103
# college     96
# address    104
# ID          96
# dtype: int64

# %%
db.astype('object').dtypes
# Out:
# names      object
# college    object
# address    object
# ID         object
# dtype: object

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   names    3 non-null      object
#  1   college  3 non-null      object
#  2   address  3 non-null      object
#  3   ID       3 non-null      object
# dtypes: object(4)
# memory usage: 112.0+ bytes

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108    NaN     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price   Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69   7.000000  26.1415   548.9715
# 1    Electronic accessories       15.28   5.000000   3.8200    80.2200
# ...

# %%
db.rename(columns={"names":"Names"})
# Out:
#     Names college  address   ID
# 0   Bimal     PES    Bihar  015
# 1  Ujjwal     PES    Bihar  112
# 2   Niyaz     PES  Kashmir  060

# %%
db["Sem"]=["6","6","6"]

# %%
db
# Out:
#     names college  address   ID Sem
# 0   Bimal     PES    Bihar  015   6
# 1  Ujjwal     PES    Bihar  112   6
# 2   Niyaz     PES  Kashmir  060   6

# %%
db.insert(2,"Branch","CSE")

# %%
db
# Out:
#     names college Branch  address   ID Sem
# 0   Bimal     PES    CSE    Bihar  015   6
# 1  Ujjwal     PES    CSE    Bihar  112   6
# 2   Niyaz     PES    CSE  Kashmir  060   6

# %%
db.loc[:,"SEC"]=list("ABB")

# %%
db
# Out:
#     names college Branch  address   ID Sem SEC
# 0   Bimal     PES    CSE    Bihar  015   6   A
# 1  Ujjwal     PES    CSE    Bihar  112   6   B
# 2   Niyaz     PES    CSE  Kashmir  060   6   B

# %%
db.value_counts()
# Out:
# names   college  Branch  address  ID   Sem  SEC
# Bimal   PES      CSE     Bihar    015  6    A      1
# Niyaz   PES      CSE     Kashmir  060  6    B      1
# Ujjwal  PES      CSE     Bihar    112  6    B      1
# dtype: int64

# %%
db.college.value_counts()
# Out:
# PES    3
# Name: college, dtype: int64

# %%
db.SEC.value_counts()
# Out:
# B    2
# A    1
# Name: SEC, dtype: int64

# %%
db.SEC.value_counts(sort=False)
# Out:
# A    1
# B    2
# Name: SEC, dtype: int64

# %%
l=db.SEC.value_counts().tolist()

# %%
l
# Out:
# [2, 1]

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108    NaN     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price   Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69   7.000000  26.1415   548.9715
# 1    Electronic accessories       15.28   5.000000   3.8200    80.2200
# ...

# %%
df.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108    NaN     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167    NaN     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974    NaN   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...

# %%
df.Branch.value_counts()
# Out:
# A    338
# B    331
# C    328
# Name: Branch, dtype: int64

# %%
b=df.Branch.value_counts().to_dict()

# %%
b
# Out:
# {'A': 338, 'B': 331, 'C': 328}

# %%
m=list(b.values()).index(max(b.values()))

# %%
m
# Out:
# 0

# %%
k=list(b.keys())[list(b.values()).index(max(b.values()))]

# %%
k
# Out:
# 'A'

# %%
df.Branch=df.Branch.fillna(k)

# %%
df.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      A   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...

# %%
df.Date.value_counts()
# Out:
# 02-07-2019    20
# 2/15/2019     19
# 03-02-2019    18
# 01-08-2019    18
# 3/14/2019     18
#               ..
# 3/21/2019      6
# 2/28/2019      6
# 2/21/2019      6
# 3/17/2019      6
# 02-01-2019     6
# Name: Date, Length: 89, dtype: int64

# %%
df["Date"].isnull().sum()
# Out:
# 2

# %%
df["Date"].head(10)
# Out:
# 0    01-05-2019
# 1    03-08-2019
# 2    03-03-2019
# 3     1/27/2019
# 4    02-08-2019
# 5     3/25/2019
# 6           NaN
# 7           NaN
# 8    01-10-2019
# 9     2/20/2019
# Name: Date, dtype: object

# %%
l=df.Date.value_counts().to_dict()

# %%
l
# Out:
# {'02-07-2019': 20,
#  '2/15/2019': 19,
#  '03-02-2019': 18,
#  '01-08-2019': 18,
#  '3/14/2019': 18,
#  '1/26/2019': 17,
#  '1/25/2019': 17,
#  '03-05-2019': 17,
#  '1/23/2019': 17,
#  '3/19/2019': 16,
#  '03-09-2019': 16,
#  '1/19/2019': 16,
#  '2/25/2019': 15,
#  '3/20/2019': 15,
#  '1/27/2019': 14,
#  '1/31/2019': 14,
#  '2/27/2019': 14,
#  '02-03-2019': 14,
#  '02-02-2019': 14,
#  '1/28/2019': 14,
#  '03-03-2019': 14,
#  '1/14/2019': 13,
#  '1/15/2019': 13,
#  '1/24/2019': 13,
#  '3/26/2019': 13,
#  '2/17/2019': 13,
#  '02-09-2019': 13,
#  '02-06-2019': 13,
#  '03-12-2019': 12,
#  '1/29/2019': 12,
#  '02-05-2019': 12,
#  '01-05-2019': 12,
#  '03-04-2019': 12,
#  '03-10-2019': 12,
#  '3/15/2019': 12,
#  '01-01-2019': 12,
#  '02-08-2019': 12,
#  '3/30/2019': 11,
#  '1/17/2019': 11,
#  '02-04-2019': 11,
#  '3/24/2019': 11,
#  '3/23/2019': 11,
#  '2/22/2019': 11,
#  '03-06-2019': 11,
#  '03-08-2019': 11,
#  '03-11-2019': 11,
#  '01-12-2019': 11,
#  '02-10-2019': 11,
# ...

# %%
k=list(l.keys())[list(l.values()).index(max(l.values()))]

# %%
k
# Out:
# '02-07-2019'

# %%
df.Date=df.Date.fillna(k)

# %%
df["Date"].head(10)
# Out:
# 0    01-05-2019
# 1    03-08-2019
# 2    03-03-2019
# 3     1/27/2019
# 4    02-08-2019
# 5     3/25/2019
# 6    02-07-2019
# 7    02-07-2019
# 8    01-10-2019
# 9     2/20/2019
# Name: Date, dtype: object

# %%
datab = pd.read_csv("C:\\Users\\Bimal Kumar\\Downloads\\supermarket_sales - Sheet1.csv")

# %%
datab
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108    NaN     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69       7.0  26.1415   548.9715
# 1    Electronic accessories       15.28       5.0   3.8200    80.2200
# ...

# %%
datab.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108    NaN     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167    NaN     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974    NaN   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...

# %%
db["Marks"]=["79","80","81"]

# %%
db
# Out:
#     names college Branch  address   ID Sem SEC Marks
# 0   Bimal     PES    CSE    Bihar  015   6   A    79
# 1  Ujjwal     PES    CSE    Bihar  112   6   B    80
# 2   Niyaz     PES    CSE  Kashmir  060   6   B    81

# %%
db.Marks.astype("int32")
# Out:
# 0    79
# 1    80
# 2    81
# Name: Marks, dtype: int32

# %%
db["DOB"]=["20001102","20000416","20000503"]

# %%
db
# Out:
#     names college Branch  address   ID Sem SEC Marks       DOB
# 0   Bimal     PES    CSE    Bihar  015   6   A    79  20001102
# 1  Ujjwal     PES    CSE    Bihar  112   6   B    80  20000416
# 2   Niyaz     PES    CSE  Kashmir  060   6   B    81  20000503

# %%
db.DOB = pd.to_datetime(db.DOB)

# %%
db
# Out:
#     names college Branch  address   ID Sem SEC Marks        DOB
# 0   Bimal     PES    CSE    Bihar  015   6   A    79 2000-11-02
# 1  Ujjwal     PES    CSE    Bihar  112   6   B    80 2000-04-16
# 2   Niyaz     PES    CSE  Kashmir  060   6   B    81 2000-05-03

# %%
temp = db.groupby('address')
for j in temp:
    print(j,end="\n\n")
# Out:
# ('Bihar',     names college Branch address   ID Sem SEC Marks        DOB
# 0   Bimal     PES    CSE   Bihar  015   6   A    79 2000-11-02
# 1  Ujjwal     PES    CSE   Bihar  112   6   B    80 2000-04-16)
#
# ('Kashmir',    names college Branch  address   ID Sem SEC Marks        DOB
# 2  Niyaz     PES    CSE  Kashmir  060   6   B    81 2000-05-03)

# %%
temp = db.groupby('SEC')
for j in temp:
    print(j,end="\n\n")
# Out:
# ('A',    names college Branch address   ID Sem SEC Marks        DOB
# 0  Bimal     PES    CSE   Bihar  015   6   A    79 2000-11-02)
#
# ('B',     names college Branch  address   ID Sem SEC Marks        DOB
# 1  Ujjwal     PES    CSE    Bihar  112   6   B    80 2000-04-16
# 2   Niyaz     PES    CSE  Kashmir  060   6   B    81 2000-05-03)

# %%
db
# Out:
#     names college Branch  address   ID Sem SEC Marks        DOB
# 0   Bimal     PES    CSE    Bihar  015   6   A    79 2000-11-02
# 1  Ujjwal     PES    CSE    Bihar  112   6   B    80 2000-04-16
# 2   Niyaz     PES    CSE  Kashmir  060   6   B    81 2000-05-03

# %%
db.sort_values(by="names",inplace=True)

# %%
db
# Out:
#     names college Branch  address   ID Sem SEC Marks        DOB
# 0   Bimal     PES    CSE    Bihar  015   6   A    79 2000-11-02
# 2   Niyaz     PES    CSE  Kashmir  060   6   B    81 2000-05-03
# 1  Ujjwal     PES    CSE    Bihar  112   6   B    80 2000-04-16

# %%
db.sort_values(by="ID",inplace=True)

# %%
db
# Out:
#     names college Branch  address   ID Sem SEC Marks        DOB
# 0   Bimal     PES    CSE    Bihar  015   6   A    79 2000-11-02
# 2   Niyaz     PES    CSE  Kashmir  060   6   B    81 2000-05-03
# 1  Ujjwal     PES    CSE    Bihar  112   6   B    80 2000-04-16

# %%
dframe=pd.DataFrame({"names":["Niyaz","Bimal","Ujjwal"],
                  "Blood Group":["B+","o+","A-"]})

# %%
dframe
# Out:
#     names Blood Group
# 0   Niyaz          B+
# 1   Bimal          o+
# 2  Ujjwal          A-

# %%
db.merge(dframe,on="names",how="right")
# Out:
#     names college Branch  address   ID Sem SEC Marks        DOB Blood Group
# 0   Niyaz     PES    CSE  Kashmir  060   6   B    81 2000-05-03          B+
# 1   Bimal     PES    CSE    Bihar  015   6   A    79 2000-11-02          o+
# 2  Ujjwal     PES    CSE    Bihar  112   6   B    80 2000-04-16          A-

# %%
datab.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108    NaN     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167    NaN     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974    NaN   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...

# %%
datab.Branch.bfill()
# Out:
# 0      A
# 1      C
# 2      A
# 3      A
# 4      A
#       ..
# 995    C
# 996    B
# 997    A
# 998    A
# 999    A
# Name: Branch, Length: 1000, dtype: object

# %%
datab.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108    NaN     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167    NaN     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974    NaN   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...

# %%
datab["Branch"] = datab.Branch.bfill()

# %%
datab.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      B     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      A   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...

# %%
datab
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69       7.0  26.1415   548.9715
# 1    Electronic accessories       15.28       5.0   3.8200    80.2200
# ...

# %%
datab["Date"] = datab.Date.bfill()

# %%
datab.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      B     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      A   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...

# %%
data = pd.read_csv("C:\\Users\\Bimal Kumar\\Downloads\\supermarket_sales - Sheet1.csv")

# %%
data.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108    NaN     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167    NaN     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974    NaN   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...

# %%
data["Branch"] = data.Branch.ffill()

# %%
data.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      C     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      C     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...

# %%
data["Date"] = data.Date.ffill()

# %%
data.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      C     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      C     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...

# %%
from sklearn.impute import SimpleImputer
import numpy as np

# %%
data = pd.read_csv("C:\\Users\\Bimal Kumar\\Downloads\\supermarket_sales - Sheet1.csv")
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108    NaN     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69       7.0  26.1415   548.9715
# 1    Electronic accessories       15.28       5.0   3.8200    80.2200
# ...

# %%
data.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108    NaN     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167    NaN     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974    NaN   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...

# %%
v=['Quantity']

# %%
imputer=SimpleImputer(missing_values=np.NaN,strategy='mean')
data[v]=imputer.fit_transform(data[v])

# %%
data.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108    NaN     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167    NaN     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974    NaN   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...

# %%
v=['Branch']

# %%
imputer=SimpleImputer(missing_values=np.NaN,strategy='most_frequent')
data[v]=imputer.fit_transform(data[v])

# %%
data.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      A   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...

# %%
v=['Date']
imputer=SimpleImputer(missing_values=np.NaN,strategy='most_frequent')
data[v]=imputer.fit_transform(data[v])

# %%
data.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      A   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...
